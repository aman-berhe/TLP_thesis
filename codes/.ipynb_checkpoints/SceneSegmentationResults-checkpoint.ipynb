# %%
from Paper_Results import TVSSegmentation #as pr
import Segmantation_lib as sg
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.DataFrame(columns=('winDiff','pk','coverage','purity','recall','precision'))
df1=pd.DataFrame(columns=('winDiff','pk','coverage','purity','recall','precision'))
dfBest=pd.DataFrame(columns=('winDiff','pk','coverage','purity','recall','precision','season','episode'))
clstAlgo=['KMeans','specteral','affinity']
#kc=[[7,5,6,4],[6,4,3,3],[9,7,7,5]]
kc=[[9,6,6,4],[7,5,4,3],[10,7,9,6]]#Game of thrones
for s in range(1,4):
    #if s==1:
        #ep=8
    #else:
      #  ep=14
    for e in range(1,11):
        print('season:',s,'episode:',e)
        try:
            trSegem=TVSSegmentation(tvs="g",season=s,episode=e)
            framesFeatures, timeStamp,shot=trSegem.load_Data()
            manScene_boundry=trSegem.load_ManAnnotation()
            _,manShot_boundry=sg.getShots(shot)
            manClstr_ref,sceneMakar=trSegem.frameGroundClusters(manShot_boundry)
            manScene_boundry=[i/1000 for i in manScene_boundry]
            avgFeatures=trSegem.getAvgFeatures(framesFeatures,timeStamp,manShot_boundry)
            randSampleFeatures=trSegem.getRandomFeat(framesFeatures,timeStamp,manShot_boundry)

            avgFeatures=np.array(avgFeatures)
            randSampleFeatures=np.array(randSampleFeatures)
            randSampleFeatures=randSampleFeatures.reshape((randSampleFeatures.shape[0],randSampleFeatures.shape[1]*randSampleFeatures.shape[2]))
            shot_TxtEmb=trSegem.getShotTextFeat(manShot_boundry)
            shot_TxtEmb=np.array(shot_TxtEmb)
            shot_TxtEmb.shape,avgFeatures.shape,randSampleFeatures.shape

            conctAvgFeat=np.concatenate((avgFeatures,shot_TxtEmb),axis=1)
            conctRandFeat=np.concatenate((randSampleFeatures,shot_TxtEmb),axis=1)
            conctAvgFeat.shape, conctRandFeat.shape

            shottimenp=np.array(manShot_boundry[0:len(conctAvgFeat)])
            conctAvgFeat_Time=np.column_stack((conctAvgFeat,shottimenp))
            conctRandFeat_Time=np.column_stack((conctRandFeat,shottimenp))
            conctAvgFeat_Time.shape, conctRandFeat_Time.shape,shottimenp.shape

            dist_AvgFeat=trSegem.getSimilarityMatrix(conctAvgFeat,'cosine')
            dist_RandFeat=trSegem.getSimilarityMatrix(conctRandFeat,'cosine') 
            dist_AvgFeat_Time=trSegem.getSimilarityMatrix(conctAvgFeat_Time,'cosine')
            dist_RandFeat_Time=trSegem.getSimilarityMatrix(conctRandFeat_Time,'cosine') 
            df_tmp=pd.DataFrame(columns=('winDiff','pk','coverage','purity','recall','precision'))

            for i, clAl in enumerate(clstAlgo):
                avgFeatClusters=trSegem.getClusters(40,clAl,dist_AvgFeat)
                randFeatClusters=trSegem.getClusters(40,clAl,dist_RandFeat)
                avgFeatClusters=avgFeatClusters.tolist()
                randFeatClusters=randFeatClusters.tolist()
                avgFeatClusters_Time=trSegem.getClusters(40,clAl,dist_AvgFeat_Time)
                randFeatClusters_Time=trSegem.getClusters(40,clAl,dist_RandFeat_Time)
                avgFeatClusters_Time=avgFeatClusters_Time.tolist()
                randFeatClusters_Time=randFeatClusters_Time.tolist()

                sepPos=sg.sequenceSegmentation(avgFeatClusters,kc[i][0],kc[i][1])
                sepPos1=sg.sequenceSegmentation(randFeatClusters,kc[i][0],kc[i][1])
                sceneTime=[]
                sceneTime1=[]
                sepPos_Time=sg.sequenceSegmentation(avgFeatClusters_Time,kc[i][2],kc[i][3])
                sepPos1_Time=sg.sequenceSegmentation(randFeatClusters_Time,kc[i][2],kc[i][3])
                sceneTime_Time=[]
                sceneTime1_Time=[]
                for i in sepPos:
                    sceneTime.append(manShot_boundry[i])
                for i in sepPos1:
                    sceneTime1.append(manShot_boundry[i])
                for i in sepPos_Time:
                    sceneTime.append(manShot_boundry[i])
                for i in sepPos1_Time:
                    sceneTime1.append(manShot_boundry[i])
                print('Auto',clAl,':',len(sepPos),len(sepPos1),len(sepPos_Time),len(sepPos1_Time),'the Manual:',len(manScene_boundry))
                tMan,tMan_bin,tMan_bin_old,sceneTime_man_bin=trSegem.getTruthValue_Man(manShot_boundry,manScene_boundry)
                len(tMan),len(tMan_bin),len(tMan_bin_old),len(sceneTime_man_bin)

                tAuto,tAuto_bin,tAuto_bin_old,sceneTime_Auto_bin=trSegem.getTruthValues_Auto(sepPos,manShot_boundry)
                tAuto1,tAuto_bin1,tAuto_bin_old1,sceneTime_Auto_bin1=trSegem.getTruthValues_Auto(sepPos1,manShot_boundry)
                tAuto_Time,tAuto_bin_Time,tAuto_bin_old_Time,sceneTime_Auto_bin_Time=trSegem.getTruthValues_Auto(sepPos_Time,manShot_boundry)
                tAuto1_Time,tAuto_bin1_Time,tAuto_bin_old1_Time,sceneTime_Auto_bin1_Time=trSegem.getTruthValues_Auto(sepPos1_Time,manShot_boundry)

                truth_valueList=[tAuto,tAuto_bin,tAuto_bin_old,tAuto1,tAuto_bin1,tAuto_bin_old1]
                truth_valueList_Time=[tAuto_Time,tAuto_bin_Time,tAuto_bin_old_Time,tAuto1_Time,tAuto_bin1_Time,tAuto_bin_old1_Time]
                truth_valueListMan=[tMan,tMan_bin,tMan_bin_old,tMan,tMan_bin,tMan_bin_old]

                for i in range(len(truth_valueList)):
                    if i%3==0:
                        results=trSegem.saveEvaluations(truth_valueListMan[i],truth_valueList[i],rType='macro')
                    else:
                        results=trSegem.saveEvaluations(truth_valueListMan[i],truth_valueList[i],rType='binary')
                    row=pd.Series({'winDiff':results[0], 'pk':results[1],'coverage':results[2],'purity':results[3],'recall':results[4],'precision':results[5],'season':str(trSegem.season),'episode':str(trSegem.episode)},name=clAl)
                    df = df.append(row)
                    df_tmp=df_tmp.append(row)

                row1=pd.Series({'winDiff':df_tmp.iloc[1][0], 'pk':df_tmp.iloc[1][1],'coverage':df_tmp.iloc[0][2],'purity':df_tmp.iloc[0][3],'recall':df_tmp.iloc[1][4],'precision':df_tmp.iloc[1][5],'season':str(trSegem.season),'episode':str(trSegem.episode)},name=clAl)
                dfBest=dfBest.append(row1)
                row1=pd.Series({'winDiff':df_tmp.iloc[4][0], 'pk':df_tmp.iloc[4][1],'coverage':df_tmp.iloc[3][2],'purity':df_tmp.iloc[3][3],'recall':df_tmp.iloc[4][4],'precision':df_tmp.iloc[4][5],'season':str(trSegem.season),'episode':str(trSegem.episode)},name=clAl)
                dfBest=dfBest.append(row1)
                df_tmp=df_tmp.drop([clAl])

                for i in range(len(truth_valueList_Time)):
                    if i%3==0:
                        results=trSegem.saveEvaluations(truth_valueListMan[i],truth_valueList_Time[i],rType='macro')
                    else:
                        results=trSegem.saveEvaluations(truth_valueListMan[i],truth_valueList_Time[i],rType='binary')
                    row=pd.Series({'winDiff':results[0], 'pk':results[1],'coverage':results[2],'purity':results[3],'recall':results[4],'precision':results[5],'season':str(trSegem.season),'episode':str(trSegem.episode)},name=clAl)
                    df1 = df1.append(row)
                    df_tmp=df_tmp.append(row)

                row1=pd.Series({'winDiff':df_tmp.iloc[1][0], 'pk':df_tmp.iloc[1][1],'coverage':df_tmp.iloc[0][2],'purity':df_tmp.iloc[0][3],'recall':df_tmp.iloc[1][4],'precision':df_tmp.iloc[1][5],'season':str(trSegem.season),'episode':str(trSegem.episode)},name=clAl)
                dfBest=dfBest.append(row1)
                row1=pd.Series({'winDiff':df_tmp.iloc[4][0], 'pk':df_tmp.iloc[4][1],'coverage':df_tmp.iloc[3][2],'purity':df_tmp.iloc[3][3],'recall':df_tmp.iloc[4][4],'precision':df_tmp.iloc[4][5],'season':str(trSegem.season),'episode':str(trSegem.episode)},name=clAl)
                dfBest=dfBest.append(row1)
                df_tmp=df_tmp.drop([clAl])
        except:
            continue
# Out:
# season: 1 episode: 1
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  1
# Episode: 1
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season01.Episode01.en.srt
# Auto KMeans : 34 29 42 39 the Manual: 44
# Auto specteral : 31 27 39 53 the Manual: 44
# Auto affinity : 34 41 32 31 the Manual: 44
# season: 1 episode: 2
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  1
# Episode: 2
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season01.Episode02.en.srt
# Auto KMeans : 28 20 35 31 the Manual: 29
# Auto specteral : 25 25 27 33 the Manual: 29
# Auto affinity : 25 32 25 28 the Manual: 29
# season: 1 episode: 3
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  1
# Episode: 3
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season01.Episode03.en.srt
# Auto KMeans : 33 29 33 33 the Manual: 30
# Auto specteral : 32 32 33 44 the Manual: 30
# Auto affinity : 31 35 33 31 the Manual: 30
# season: 1 episode: 4
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  1
# Episode: 4
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season01.Episode04.en.srt
# Auto KMeans : 26 24 33 34 the Manual: 29
# Auto specteral : 23 27 27 40 the Manual: 29
# Auto affinity : 26 32 29 32 the Manual: 29
# season: 1 episode: 5
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  1
# Episode: 5
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season01.Episode05.en.srt
# Auto KMeans : 26 24 31 37 the Manual: 23
# Auto specteral : 26 29 32 45 the Manual: 23
# Auto affinity : 27 34 27 39 the Manual: 23
# season: 1 episode: 6
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  1
# Episode: 6
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season01.Episode06.en.srt
# Auto KMeans : 32 30 41 43 the Manual: 20
# Auto specteral : 28 34 41 55 the Manual: 20
# Auto affinity : 33 39 29 40 the Manual: 20
# season: 1 episode: 7
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  1
# Episode: 7
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season01.Episode07.en.srt
# Auto KMeans : 28 25 29 32 the Manual: 24
# Auto specteral : 26 28 29 43 the Manual: 24
# Auto affinity : 29 29 32 33 the Manual: 24
# season: 1 episode: 8
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  1
# Episode: 8
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season01.Episode08.en.srt
# Auto KMeans : 32 28 41 37 the Manual: 35
# Auto specteral : 34 30 36 39 the Manual: 35
# Auto affinity : 33 39 37 41 the Manual: 35
# season: 1 episode: 9
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  1
# Episode: 9
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season01.Episode09.en.srt
# Auto KMeans : 27 24 37 30 the Manual: 20
# Auto specteral : 27 31 29 38 the Manual: 20
# Auto affinity : 27 31 28 29 the Manual: 20
# season: 1 episode: 10
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  1
# Episode: 10
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season01.Episode10.en.srt
# Auto KMeans : 22 22 26 26 the Manual: 26
# Auto specteral : 22 26 26 36 the Manual: 26
# Auto affinity : 21 25 26 24 the Manual: 26
# season: 2 episode: 1
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  2
# Episode: 1
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season02.Episode01.en.srt
# Auto KMeans : 22 19 22 24 the Manual: 21
# Auto specteral : 22 21 23 26 the Manual: 21
# Auto affinity : 21 31 29 33 the Manual: 21
# season: 2 episode: 2
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  2
# Episode: 2
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season02.Episode02.en.srt
# Auto KMeans : 22 18 28 22 the Manual: 19
# Auto specteral : 21 22 27 28 the Manual: 19
# Auto affinity : 20 25 26 24 the Manual: 19
# season: 2 episode: 3
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  2
# Episode: 3
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season02.Episode03.en.srt
# season: 2 episode: 4
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  2
# Episode: 4
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season02.Episode04.en.srt
# Auto KMeans : 23 18 24 25 the Manual: 20
# Auto specteral : 20 22 35 43 the Manual: 20
# Auto affinity : 25 27 31 24 the Manual: 20
# season: 2 episode: 5
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  2
# Episode: 5
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season02.Episode05.en.srt
# Auto KMeans : 27 25 35 30 the Manual: 22
# Auto specteral : 24 28 29 48 the Manual: 22
# Auto affinity : 27 32 34 31 the Manual: 22
# season: 2 episode: 6
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  2
# Episode: 6
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season02.Episode06.en.srt
# Auto KMeans : 26 22 40 37 the Manual: 20
# Auto specteral : 28 28 35 45 the Manual: 20
# Auto affinity : 29 34 32 33 the Manual: 20
# season: 2 episode: 7
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  2
# Episode: 7
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season02.Episode07.en.srt
# Auto KMeans : 28 21 35 31 the Manual: 26
# Auto specteral : 29 26 28 38 the Manual: 26
# Auto affinity : 26 34 30 33 the Manual: 26
# season: 2 episode: 8
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  2
# Episode: 8
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season02.Episode08.en.srt
# Auto KMeans : 22 17 20 22 the Manual: 22
# Auto specteral : 20 19 27 28 the Manual: 22
# Auto affinity : 18 25 21 24 the Manual: 22
# season: 2 episode: 9
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  2
# Episode: 9
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season02.Episode09.en.srt
# season: 2 episode: 10
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  2
# Episode: 10
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season02.Episode10.en.srt
# season: 3 episode: 1
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  3
# Episode: 1
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season03.Episode01.en.srt
# Auto KMeans : 24 21 30 38 the Manual: 22
# Auto specteral : 21 24 31 40 the Manual: 22
# Auto affinity : 26 32 29 29 the Manual: 22
# season: 3 episode: 2
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  3
# Episode: 2
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season03.Episode02.en.srt
# Auto KMeans : 24 22 29 26 the Manual: 23
# Auto specteral : 24 23 29 39 the Manual: 23
# Auto affinity : 25 30 27 27 the Manual: 23
# season: 3 episode: 3
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  3
# Episode: 3
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season03.Episode03.en.srt
# season: 3 episode: 4
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  3
# Episode: 4
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season03.Episode04.en.srt
# Auto KMeans : 27 24 30 38 the Manual: 21
# Auto specteral : 33 29 35 37 the Manual: 21
# Auto affinity : 34 38 35 37 the Manual: 21
# season: 3 episode: 5
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  3
# Episode: 5
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season03.Episode05.en.srt
# Auto KMeans : 36 31 38 36 the Manual: 26
# Auto specteral : 29 24 34 47 the Manual: 26
# Auto affinity : 34 43 46 57 the Manual: 26
# season: 3 episode: 6
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  3
# Episode: 6
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season03.Episode06.en.srt
# season: 3 episode: 7
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  3
# Episode: 7
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season03.Episode07.en.srt
# Auto KMeans : 24 21 31 28 the Manual: 22
# Auto specteral : 26 32 31 35 the Manual: 22
# Auto affinity : 26 32 29 30 the Manual: 22
# season: 3 episode: 8
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  3
# Episode: 8
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season03.Episode08.en.srt
# Auto KMeans : 28 20 26 26 the Manual: 18
# Auto specteral : 26 23 35 33 the Manual: 18
# Auto affinity : 22 31 33 29 the Manual: 18
# season: 3 episode: 9
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  3
# Episode: 9
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season03.Episode09.en.srt
# season: 3 episode: 10
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  3
# Episode: 10
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season03.Episode10.en.srt
# Auto KMeans : 32 27 30 35 the Manual: 27
# Auto specteral : 26 26 27 42 the Manual: 27
# Auto affinity : 33 36 39 34 the Manual: 27

# %%
df.to_csv('ResultsPaper/GoT/Results_segmentaion_TextEmbe_Augemnted_training2.csv')
df1.to_csv('ResultsPaper/GoT/Results_segmentaion_TimeAugmented_training2.csv')
dfBest.to_csv('ResultsPaper/GoT/Results_segmentaion_Features_training2.csv')

# %%
df=pd.DataFrame(columns=('winDiff','pk','coverage','purity','recall','precision'))
df1=pd.DataFrame(columns=('winDiff','pk','coverage','purity','recall','precision'))
dfBest=pd.DataFrame(columns=('winDiff','pk','coverage','purity','recall','precision','season','episode'))
clstAlgo=['KMeans','specteral','affinity']
kc=[[7,5,6,4],[6,4,3,3],[9,7,7,5]]
s=3
for s in range(4,6):
    for e in range(1,11):
        print('season:',s,'episode:',e)
        try:
            trSegem=TVSSegmentation(tvs="g",season=s,episode=e)
            framesFeatures, timeStamp,shot=trSegem.load_Data()
            manScene_boundry=trSegem.load_ManAnnotation()
            _,manShot_boundry=sg.getShots(shot)
            manClstr_ref,sceneMakar=trSegem.frameGroundClusters(manShot_boundry)
            manScene_boundry=[i/1000 for i in manScene_boundry]
            avgFeatures=trSegem.getAvgFeatures(framesFeatures,timeStamp,manShot_boundry)
            randSampleFeatures=trSegem.getRandomFeat(framesFeatures,timeStamp,manShot_boundry)

            avgFeatures=np.array(avgFeatures)
            randSampleFeatures=np.array(randSampleFeatures)
            randSampleFeatures=randSampleFeatures.reshape((randSampleFeatures.shape[0],randSampleFeatures.shape[1]*randSampleFeatures.shape[2]))
            shot_TxtEmb=trSegem.getShotTextFeat(manShot_boundry)
            shot_TxtEmb=np.array(shot_TxtEmb)
            shot_TxtEmb.shape,avgFeatures.shape,randSampleFeatures.shape

            conctAvgFeat=np.concatenate((avgFeatures,shot_TxtEmb),axis=1)
            conctRandFeat=np.concatenate((randSampleFeatures,shot_TxtEmb),axis=1)
            conctAvgFeat.shape, conctRandFeat.shape

            shottimenp=np.array(manShot_boundry[0:len(conctAvgFeat)])
            conctAvgFeat_Time=np.column_stack((conctAvgFeat,shottimenp))
            conctRandFeat_Time=np.column_stack((conctRandFeat,shottimenp))
            conctAvgFeat_Time.shape, conctRandFeat_Time.shape,shottimenp.shape

            dist_AvgFeat=trSegem.getSimilarityMatrix(conctAvgFeat,'cosine')
            dist_RandFeat=trSegem.getSimilarityMatrix(conctRandFeat,'cosine') 
            dist_AvgFeat_Time=trSegem.getSimilarityMatrix(conctAvgFeat_Time,'cosine')
            dist_RandFeat_Time=trSegem.getSimilarityMatrix(conctRandFeat_Time,'cosine') 
            df_tmp=pd.DataFrame(columns=('winDiff','pk','coverage','purity','recall','precision'))

            for i, clAl in enumerate(clstAlgo):
                avgFeatClusters=trSegem.getClusters(40,clAl,dist_AvgFeat)
                randFeatClusters=trSegem.getClusters(40,clAl,dist_RandFeat)
                avgFeatClusters=avgFeatClusters.tolist()
                randFeatClusters=randFeatClusters.tolist()
                avgFeatClusters_Time=trSegem.getClusters(40,clAl,dist_AvgFeat_Time)
                randFeatClusters_Time=trSegem.getClusters(40,clAl,dist_RandFeat_Time)
                avgFeatClusters_Time=avgFeatClusters_Time.tolist()
                randFeatClusters_Time=randFeatClusters_Time.tolist()

                sepPos=sg.sequenceSegmentation(avgFeatClusters,kc[i][0],kc[i][1])
                sepPos1=sg.sequenceSegmentation(randFeatClusters,kc[i][0],kc[i][1])
                sceneTime=[]
                sceneTime1=[]
                sepPos_Time=sg.sequenceSegmentation(avgFeatClusters_Time,kc[i][2],kc[i][3])
                sepPos1_Time=sg.sequenceSegmentation(randFeatClusters_Time,kc[i][2],kc[i][3])
                sceneTime_Time=[]
                sceneTime1_Time=[]
                for i in sepPos:
                    sceneTime.append(manShot_boundry[i])
                for i in sepPos1:
                    sceneTime1.append(manShot_boundry[i])
                for i in sepPos_Time:
                    sceneTime.append(manShot_boundry[i])
                for i in sepPos1_Time:
                    sceneTime1.append(manShot_boundry[i])
                print('Auto',clAl,':',len(sepPos),len(sepPos1),len(sepPos_Time),len(sepPos1_Time),'the Manual:',len(manScene_boundry))
                tMan,tMan_bin,tMan_bin_old,sceneTime_man_bin=trSegem.getTruthValue_Man(manShot_boundry,manScene_boundry)
                len(tMan),len(tMan_bin),len(tMan_bin_old),len(sceneTime_man_bin)

                tAuto,tAuto_bin,tAuto_bin_old,sceneTime_Auto_bin=trSegem.getTruthValues_Auto(sepPos,manShot_boundry)
                tAuto1,tAuto_bin1,tAuto_bin_old1,sceneTime_Auto_bin1=trSegem.getTruthValues_Auto(sepPos1,manShot_boundry)
                tAuto_Time,tAuto_bin_Time,tAuto_bin_old_Time,sceneTime_Auto_bin_Time=trSegem.getTruthValues_Auto(sepPos_Time,manShot_boundry)
                tAuto1_Time,tAuto_bin1_Time,tAuto_bin_old1_Time,sceneTime_Auto_bin1_Time=trSegem.getTruthValues_Auto(sepPos1_Time,manShot_boundry)

                truth_valueList=[tAuto,tAuto_bin,tAuto_bin_old,tAuto1,tAuto_bin1,tAuto_bin_old1]
                truth_valueList_Time=[tAuto_Time,tAuto_bin_Time,tAuto_bin_old_Time,tAuto1_Time,tAuto_bin1_Time,tAuto_bin_old1_Time]
                truth_valueListMan=[tMan,tMan_bin,tMan_bin_old,tMan,tMan_bin,tMan_bin_old]

                for i in range(len(truth_valueList)):
                    if i%3==0:
                        results=trSegem.saveEvaluations(truth_valueListMan[i],truth_valueList[i],rType='macro')
                    else:
                        results=trSegem.saveEvaluations(truth_valueListMan[i],truth_valueList[i],rType='binary')
                    row=pd.Series({'winDiff':results[0], 'pk':results[1],'coverage':results[2],'purity':results[3],'recall':results[4],'precision':results[5],'season':str(trSegem.season),'episode':str(trSegem.episode)},name=clAl)
                    df = df.append(row)
                    df_tmp=df_tmp.append(row)

                row1=pd.Series({'winDiff':df_tmp.iloc[1][0], 'pk':df_tmp.iloc[1][1],'coverage':df_tmp.iloc[0][2],'purity':df_tmp.iloc[0][3],'recall':df_tmp.iloc[1][4],'precision':df_tmp.iloc[1][5],'season':str(trSegem.season),'episode':str(trSegem.episode)},name=clAl)
                dfBest=dfBest.append(row1)
                row1=pd.Series({'winDiff':df_tmp.iloc[4][0], 'pk':df_tmp.iloc[4][1],'coverage':df_tmp.iloc[3][2],'purity':df_tmp.iloc[3][3],'recall':df_tmp.iloc[4][4],'precision':df_tmp.iloc[4][5],'season':str(trSegem.season),'episode':str(trSegem.episode)},name=clAl)
                dfBest=dfBest.append(row1)
                df_tmp=df_tmp.drop([clAl])

                for i in range(len(truth_valueList_Time)):
                    if i%3==0:
                        results=trSegem.saveEvaluations(truth_valueListMan[i],truth_valueList_Time[i],rType='macro')
                    else:
                        results=trSegem.saveEvaluations(truth_valueListMan[i],truth_valueList_Time[i],rType='binary')
                    row=pd.Series({'winDiff':results[0], 'pk':results[1],'coverage':results[2],'purity':results[3],'recall':results[4],'precision':results[5],'season':str(trSegem.season),'episode':str(trSegem.episode)},name=clAl)
                    df1 = df1.append(row)
                    df_tmp=df_tmp.append(row)

                row1=pd.Series({'winDiff':df_tmp.iloc[1][0], 'pk':df_tmp.iloc[1][1],'coverage':df_tmp.iloc[0][2],'purity':df_tmp.iloc[0][3],'recall':df_tmp.iloc[1][4],'precision':df_tmp.iloc[1][5],'season':str(trSegem.season),'episode':str(trSegem.episode)},name=clAl)
                dfBest=dfBest.append(row1)
                row1=pd.Series({'winDiff':df_tmp.iloc[4][0], 'pk':df_tmp.iloc[4][1],'coverage':df_tmp.iloc[3][2],'purity':df_tmp.iloc[3][3],'recall':df_tmp.iloc[4][4],'precision':df_tmp.iloc[4][5],'season':str(trSegem.season),'episode':str(trSegem.episode)},name=clAl)
                dfBest=dfBest.append(row1)
                df_tmp=df_tmp.drop([clAl])
        except:
            continue
# Out:
# season: 4 episode: 1
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  4
# Episode: 1
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season04.Episode01.en.srt
# Auto KMeans : 38 35 30 27 the Manual: 22
# Auto specteral : 34 41 31 37 the Manual: 22
# Auto affinity : 31 39 38 44 the Manual: 22
# season: 4 episode: 2
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  4
# Episode: 2
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season04.Episode02.en.srt
# Auto KMeans : 39 36 33 30 the Manual: 16
# Auto specteral : 35 40 33 61 the Manual: 16
# Auto affinity : 33 42 52 49 the Manual: 16
# season: 4 episode: 3
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  4
# Episode: 3
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season04.Episode03.en.srt
# Auto KMeans : 40 33 30 33 the Manual: 19
# Auto specteral : 44 39 36 55 the Manual: 19
# Auto affinity : 31 37 56 49 the Manual: 19
# season: 4 episode: 4
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  4
# Episode: 4
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season04.Episode04.en.srt
# Auto KMeans : 40 30 28 27 the Manual: 25
# Auto specteral : 32 37 35 29 the Manual: 25
# Auto affinity : 21 28 37 35 the Manual: 25
# season: 4 episode: 5
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  4
# Episode: 5
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season04.Episode05.en.srt
# Auto KMeans : 34 27 22 29 the Manual: 28
# Auto specteral : 32 36 29 32 the Manual: 28
# Auto affinity : 22 27 30 32 the Manual: 28
# season: 4 episode: 6
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  4
# Episode: 6
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season04.Episode06.en.srt
# Auto KMeans : 32 27 23 30 the Manual: 15
# Auto specteral : 33 32 40 43 the Manual: 15
# Auto affinity : 24 27 31 33 the Manual: 15
# season: 4 episode: 7
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  4
# Episode: 7
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season04.Episode07.en.srt
# Auto KMeans : 33 25 30 28 the Manual: 17
# Auto specteral : 29 32 30 39 the Manual: 17
# Auto affinity : 25 27 42 39 the Manual: 17
# season: 4 episode: 8
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  4
# Episode: 8
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season04.Episode08.en.srt
# Auto KMeans : 32 29 31 37 the Manual: 21
# Auto specteral : 35 33 49 62 the Manual: 21
# Auto affinity : 23 33 37 39 the Manual: 21
# season: 4 episode: 9
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  4
# Episode: 9
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season04.Episode09.en.srt
# season: 4 episode: 10
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  4
# Episode: 10
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season04.Episode10.en.srt
# season: 5 episode: 1
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  5
# Episode: 1
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season05.Episode01.en.srt
# Auto KMeans : 30 29 27 24 the Manual: 24
# Auto specteral : 27 32 35 35 the Manual: 24
# Auto affinity : 23 25 28 33 the Manual: 24
# season: 5 episode: 2
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  5
# Episode: 2
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season05.Episode02.en.srt
# Auto KMeans : 38 34 27 29 the Manual: 26
# Auto specteral : 34 42 32 39 the Manual: 26
# Auto affinity : 32 32 38 40 the Manual: 26
# season: 5 episode: 3
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  5
# Episode: 3
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season05.Episode03.en.srt
# Auto KMeans : 38 34 29 29 the Manual: 29
# Auto specteral : 32 35 30 29 the Manual: 29
# Auto affinity : 25 38 39 39 the Manual: 29
# season: 5 episode: 4
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  5
# Episode: 4
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season05.Episode04.en.srt
# Auto KMeans : 42 31 34 33 the Manual: 25
# Auto specteral : 36 40 38 44 the Manual: 25
# Auto affinity : 25 36 42 39 the Manual: 25
# season: 5 episode: 5
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  5
# Episode: 5
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season05.Episode05.en.srt
# Auto KMeans : 42 36 32 41 the Manual: 24
# Auto specteral : 41 41 40 48 the Manual: 24
# Auto affinity : 29 34 44 42 the Manual: 24
# season: 5 episode: 6
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  5
# Episode: 6
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season05.Episode06.en.srt
# Auto KMeans : 33 32 22 26 the Manual: 24
# Auto specteral : 37 32 32 45 the Manual: 24
# Auto affinity : 22 27 33 29 the Manual: 24
# season: 5 episode: 7
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  5
# Episode: 7
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season05.Episode07.en.srt
# Auto KMeans : 46 38 31 32 the Manual: 26
# Auto specteral : 40 41 27 41 the Manual: 26
# Auto affinity : 29 39 43 39 the Manual: 26
# season: 5 episode: 8
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  5
# Episode: 8
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season05.Episode08.en.srt
# Auto KMeans : 44 34 29 31 the Manual: 15
# Auto specteral : 37 46 30 43 the Manual: 15
# Auto affinity : 26 41 47 39 the Manual: 15
# season: 5 episode: 9
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  5
# Episode: 9
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season05.Episode09.en.srt
# Auto KMeans : 43 43 35 37 the Manual: 20
# Auto specteral : 47 47 36 68 the Manual: 20
# Auto affinity : 28 45 48 48 the Manual: 20
# season: 5 episode: 10
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  5
# Episode: 10
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season05.Episode10.en.srt
# Auto KMeans : 41 41 33 32 the Manual: 29
# Auto specteral : 39 36 43 56 the Manual: 29
# Auto affinity : 27 36 43 43 the Manual: 29

# %%
df.to_csv('ResultsPaper/GoT/Results_segmentaion_TextEmbe_Augemnted_test2.csv')
df1.to_csv('ResultsPaper/GoT/Results_segmentaion_TimeAugmented_test2.csv')
dfBest.to_csv('ResultsPaper/GoT/Results_segmentaion_Features_test2.csv')

# %%
dfBest
# Out:
#            winDiff     pk  coverage  purity  recall  precision season episode
# KMeans       0.108  0.060     0.649   0.884   0.961      0.977      4       1
# KMeans       0.087  0.049     0.701   0.934   0.968      0.982      4       1
# KMeans       0.095  0.050     0.702   0.698   0.970      0.979      4       1
# KMeans       0.085  0.047     0.752   0.709   0.974      0.979      4       1
# specteral    0.101  0.054     0.676   0.908   0.966      0.979      4       1
# specteral    0.106  0.057     0.592   0.925   0.961      0.981      4       1
# specteral    0.099  0.051     0.807   0.431   0.969      0.979      4       1
# specteral    0.106  0.057     0.791   0.531   0.963      0.978      4       1
# affinity     0.087  0.047     0.653   0.903   0.971      0.981      4       1
# affinity     0.097  0.053     0.643   0.952   0.964      0.982      4       1
# affinity     0.120  0.062     0.711   0.606   0.960      0.976      4       1
# affinity     0.118  0.064     0.641   0.743   0.956      0.978      4       1
# KMeans       0.088  0.049     0.514   0.932   0.965      0.986      4       2
# KMeans       0.083  0.042     0.499   0.928   0.969      0.988      4       2
# KMeans       0.074  0.041     0.539   0.914   0.971      0.987      4       2
# KMeans       0.072  0.040     0.580   0.901   0.973      0.986      4       2
# specteral    0.087  0.043     0.492   0.895   0.969      0.987      4       2
# specteral    0.094  0.050     0.497   0.902   0.964      0.986      4       2
# specteral    0.083  0.043     0.793   0.661   0.970      0.986      4       2
# specteral    0.125  0.063     0.494   0.890   0.947      0.988      4       2
# affinity     0.074  0.040     0.512   0.874   0.972      0.988      4       2
# affinity     0.088  0.046     0.477   0.940   0.965      0.989      4       2
# affinity     0.110  0.055     0.460   0.835   0.955      0.988      4       2
# affinity     0.109  0.056     0.469   0.833   0.956      0.987      4       2
# KMeans       0.088  0.047     0.555   0.933   0.966      0.986      4       3
# KMeans       0.071  0.044     0.679   0.857   0.971      0.984      4       3
# KMeans       0.081  0.043     0.663   0.797   0.973      0.983      4       3
# KMeans       0.077  0.040     0.622   0.894   0.973      0.986      4       3
# specteral    0.097  0.050     0.593   0.906   0.963      0.986      4       3
# specteral    0.081  0.048     0.615   0.927   0.966      0.985      4       3
# ...            ...    ...       ...     ...     ...        ...    ...     ...
# specteral    0.078  0.041     0.822   0.645   0.972      0.986      5       8
# specteral    0.095  0.049     0.794   0.717   0.961      0.988      5       8
# affinity     0.065  0.037     0.554   0.957   0.976      0.986      5       8
# affinity     0.086  0.046     0.481   0.958   0.964      0.989      5       8
# affinity     0.105  0.053     0.750   0.747   0.958      0.988      5       8
# affinity     0.084  0.044     0.795   0.759   0.966      0.989      5       8
# KMeans       0.089  0.048     0.563   0.932   0.965      0.986      5       9
# KMeans       0.089  0.048     0.529   0.932   0.965      0.986      5       9
# KMeans       0.079  0.041     0.655   0.815   0.972      0.986      5       9
# KMeans       0.089  0.048     0.603   0.835   0.968      0.983      5       9
# specteral    0.109  0.057     0.484   0.899   0.959      0.983      5       9
# specteral    0.093  0.053     0.525   0.942   0.961      0.985      5       9
# specteral    0.095  0.049     0.841   0.565   0.968      0.982      5       9
# specteral    0.136  0.070     0.495   0.846   0.942      0.986      5       9
# affinity     0.068  0.036     0.583   0.858   0.978      0.985      5       9
# affinity     0.093  0.048     0.527   0.953   0.964      0.987      5       9
# affinity     0.104  0.056     0.583   0.733   0.959      0.984      5       9
# affinity     0.113  0.058     0.644   0.787   0.958      0.983      5       9
# KMeans       0.122  0.066     0.683   0.890   0.959      0.973      5      10
# KMeans       0.111  0.063     0.690   0.892   0.961      0.974      5      10
# KMeans       0.107  0.059     0.722   0.826   0.967      0.972      5      10
# KMeans       0.120  0.064     0.729   0.812   0.965      0.968      5      10
# specteral    0.107  0.061     0.657   0.912   0.963      0.974      5      10
# specteral    0.118  0.064     0.721   0.852   0.963      0.970      5      10
# specteral    0.144  0.079     0.816   0.705   0.952      0.967      5      10
# specteral    0.149  0.080     0.755   0.864   0.944      0.973      5      10
# affinity     0.094  0.052     0.782   0.836   0.974      0.972      5      10
# affinity     0.118  0.060     0.623   0.880   0.965      0.973      5      10
# affinity     0.129  0.070     0.738   0.740   0.956      0.971      5      10
# affinity     0.127  0.070     0.759   0.853   0.956      0.971      5      10
#
# [216 rows x 8 columns]

# %%
trSegem.fileName

# %%
trSegem=TVSSegmentation(tvs="g",season=1,episode=11)
# Out:
# You have chosen :
# Tv-Series: Game of Thrones
# Season:  1
# Episode: 11
# Subtile File :  /people/berhe/Bureau/TLP_thesis/subtitles/GoT/English/GameOfThrones.Season01.Episode11.en.srt
