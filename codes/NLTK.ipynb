# %%
import nltk
# Out:
# /home/berhe/anaconda3/envs/Lxml/lib/python3.5/site-packages/sklearn/utils/fixes.py:313: FutureWarning: numpy not_equal will not check object identity in the future. The comparison did not return the same result as suggested by the identity (`is`)) and will change.
#   _nan_object_mask = _nan_object_array != _nan_object_array

# %%
import sys
sys.executable
# Out:
# '/home/berhe/anaconda3/envs/Lxml/bin/python'

# %%
print("try to print")
# Out:
# try to print

# %% [markdown]
# $$c = \sqrt{a^2 + b^2}$$

# %%
sentence = "At eight o'clock on Thursday morning Arthur didn't feel very good. new line Aman is coming"

# %%
print (sentence)
# Out:
# At eight o'clock on Thursday morning Arthur didn't feel very good. new line Aman is coming

# %%
tokens=nltk.word_tokenize(sentence,language='english',preserve_line=False)

# %%
tokens
# Out:
# ['At',
#  'eight',
#  "o'clock",
#  'on',
#  'Thursday',
#  'morning',
#  'Arthur',
#  'did',
#  "n't",
#  'feel',
#  'very',
#  'good',
#  '.',
#  'new',
#  'line',
#  'Aman',
#  'is',
#  'coming']

# %%
tagged=nltk.pos_tag(tokens)

# %%
tagged
# Out:
# [('At', 'IN'),
#  ('eight', 'CD'),
#  ("o'clock", 'NN'),
#  ('on', 'IN'),
#  ('Thursday', 'NNP'),
#  ('morning', 'NN'),
#  ('Arthur', 'NNP'),
#  ('did', 'VBD'),
#  ("n't", 'RB'),
#  ('feel', 'VB'),
#  ('very', 'RB'),
#  ('good', 'JJ'),
#  ('.', '.'),
#  ('new', 'JJ'),
#  ('line', 'NN'),
#  ('Aman', 'NNP'),
#  ('is', 'VBZ'),
#  ('coming', 'VBG')]

# %%
tagged[0:6]
# Out:
# [('At', 'IN'),
#  ('eight', 'CD'),
#  ("o'clock", 'NN'),
#  ('on', 'IN'),
#  ('Thursday', 'NNP'),
#  ('morning', 'NN')]

# %%
entities=nltk.chunk.ne_chunk(tagged)

# %%
entities
# Out:
# Tree('S', [('At', 'IN'), ('eight', 'CD'), ("o'clock", 'NN'), ('on', 'IN'), ('Thursday', 'NNP'), ('morning', 'NN'), Tree('PERSON', [('Arthur', 'NNP')]), ('did', 'VBD'), ("n't", 'RB'), ('feel', 'VB'), ('very', 'RB'), ('good', 'JJ'), ('.', '.'), ('new', 'JJ'), ('line', 'NN'), Tree('PERSON', [('Aman', 'NNP')]), ('is', 'VBZ'), ('coming', 'VBG')])

# %%
def has_no_text(line):
    l=line.strip()
    if not len(l):
        return True
    if l.isdigit():
        return True
    else:
        return False

# %%
def clean_line(lines):
    new_lines=[]
    for line in lines[1:]:
        if has_no_text(line):
            continue
        elif len(new_lines):
            new_lines[-1]=new_lines[-1].strip() + ' ' + line
        else:
            new_lines.append(line)
    return new_lines

# %%
f=open('/home/berhe/Desktop/LIMSI/TLP_thesis/subtitles/GameOfThrones.Season01.Episode01.en.srt')

# %%
lines=f.readlines()
new_lines=clean_line(lines)
print (len(new_lines))
# Out:
# 1

# %%
lines
# Out:
# ['1\n',
#  '00:00:10,599 --> 00:00:13,113\n',
#  '(Gate rumbling, chains rattling)\n',
#  '\n',
#  '\n',
#  '\n',
#  '2\n',
#  '00:00:41,120 --> 00:00:43,156\n',
#  '(Horse snorts)\n',
#  '\n',
#  '\n',
#  '\n',
#  '3\n',
#  '00:00:55,520 --> 00:00:57,397\n',
#  '(Rumbling, chain rattling)\n',
#  '\n',
#  '\n',
#  '\n',
#  '4\n',
#  '00:01:40,159 --> 00:01:41,717\n',
#  '(Wind whistling)\n',
#  '\n',
#  '\n',
#  '\n',
#  '5\n',
#  '00:01:52,639 --> 00:01:54,789\n',
#  '- Easy, boy.\n',
#  '- (Grunts)\n',
#  '\n',
#  '\n',
#  '\n',
#  '6\n',
#  '00:02:53,760 --> 00:02:55,796\n',
#  '(Horse whinnies)\n',
#  '\n',
#  '\n',
#  '\n',
#  '7\n',
#  '00:03:04,799 --> 00:03:06,755\n',
#  '(Man) What do you expect?\n',
#  "They're savages.\n",
#  '\n',
#  '\n',
#  '\n',
#  '8\n',
#  '00:03:06,880 --> 00:03:09,110\n',
#  'One lot steals a goat from another lot,\n',
#  '\n',
#  '\n',
#  '\n',
#  '9\n',
#  '00:03:09,240 --> 00:03:11,515\n',
#  'before you know it\n',
#  "they're ripping each other to pieces.\n",
#  '\n',
#  '\n',
#  '\n',
#  '10\n',
#  '00:03:11,639 --> 00:03:13,948\n',
#  "I've never seen wildlings do a thing like this.\n",
#  '\n',
#  '\n',
#  '\n',
#  '11\n',
#  '00:03:14,080 --> 00:03:16,196\n',
#  'I never seen a thing like this,\n',
#  'not ever in my life.\n',
#  '\n',
#  '\n',
#  '\n',
#  '12\n',
#  '00:03:16,319 --> 00:03:18,389\n',
#  '- (Horse snorts)\n',
#  '- How close did you get?\n',
#  '\n',
#  '\n',
#  '\n',
#  '13\n',
#  '00:03:18,480 --> 00:03:21,756\n',
#  '- Close as any man would.\n',
#  '- We should head back to the Wall.\n',
#  '\n',
#  '\n',
#  '\n',
#  '14\n',
#  '00:03:24,280 --> 00:03:25,679\n',
#  'Do the dead frighten you?\n',
#  '\n',
#  '\n',
#  '\n',
#  '15\n',
#  '00:03:25,840 --> 00:03:27,876\n',
#  'Our orders were to track the wildlings.\n',
#  '\n',
#  '\n',
#  '\n',
#  '16\n',
#  '00:03:27,999 --> 00:03:31,036\n',
#  'We tracked them.\n',
#  'They won‘t trouble us no more.\n',
#  '\n',
#  '\n',
#  '\n',
#  '17\n',
#  '00:03:31,159 --> 00:03:33,514\n',
#  "You don‘t think he'll ask us how they died?\n",
#  '\n',
#  '\n',
#  '\n',
#  '18\n',
#  '00:03:35,679 --> 00:03:37,397\n',
#  'Get back on your horse.\n',
#  '\n',
#  '\n',
#  '\n',
#  '19\n',
#  '00:03:38,879 --> 00:03:40,676\n',
#  '(Sighs, mutters)\n',
#  '\n',
#  '\n',
#  '\n',
#  '20\n',
#  '00:03:41,879 --> 00:03:44,313\n',
#  'Whatever did it to them\n',
#  'could do it to us.\n',
#  '\n',
#  '\n',
#  '\n',
#  '21\n',
#  '00:03:44,400 --> 00:03:45,958\n',
#  'They even killed the children.\n',
#  '\n',
#  '\n',
#  '\n',
#  '22\n',
#  '00:03:46,840 --> 00:03:48,751\n',
#  "It's a good thing we're not children.\n",
#  '\n',
#  '\n',
#  '\n',
#  '23\n',
#  '00:03:50,079 --> 00:03:52,798\n',
#  'You want to run away south,\n',
#  'run away.\n',
#  '\n',
#  '\n',
#  '\n',
#  '24\n',
#  '00:03:52,920 --> 00:03:55,718\n',
#  'Of course,\n',
#  'they will behead you as a deserter.\n',
#  '\n',
#  '\n',
#  '\n',
#  '25\n',
#  '00:03:55,840 --> 00:03:57,831\n',
#  "If I don't catch you ﬁrst.\n",
#  '\n',
#  '\n',
#  '\n',
#  '26\n',
#  '00:04:00,120 --> 00:04:02,350\n',
#  'Get back on your horse.\n',
#  '\n',
#  '\n',
#  '\n',
#  '27\n',
#  '00:04:02,480 --> 00:04:04,675\n',
#  "I won't say it again.\n",
#  '\n',
#  '\n',
#  '\n',
#  '28\n',
#  '00:04:21,639 --> 00:04:23,675\n',
#  '(Shrill animal ll)\n',
#  '\n',
#  '\n',
#  '\n',
#  '29\n',
#  '00:04:34,519 --> 00:04:36,953\n',
#  'Your dead men seem\n',
#  'to have moved mp.\n',
#  '\n',
#  '\n',
#  '\n',
#  '30\n',
#  '00:04:37,600 --> 00:04:39,192\n',
#  'They were here.\n',
#  '\n',
#  '\n',
#  '\n',
#  '31\n',
#  '00:04:42,440 --> 00:04:44,032\n',
#  'See where they went.\n',
#  '\n',
#  '\n',
#  '\n',
#  '32\n',
#  '00:04:58,840 --> 00:05:01,400\n',
#  '(Echoing creature cries)\n',
#  '\n',
#  '\n',
#  '\n',
#  '33\n',
#  '00:05:28,639 --> 00:05:30,436\n',
#  'What is it?\n',
#  '\n',
#  '\n',
#  '\n',
#  '34\n',
#  '00:05:31,720 --> 00:05:32,755\n',
#  "It's...\n",
#  '\n',
#  '\n',
#  '\n',
#  '35\n',
#  '00:05:33,800 --> 00:05:35,597\n',
#  '(Cracking, creaking)\n',
#  '\n',
#  '\n',
#  '\n',
#  '36\n',
#  '00:05:37,840 --> 00:05:39,831\n',
#  '(Distant scream)\n',
#  '\n',
#  '\n',
#  '\n',
#  '37\n',
#  '00:05:39,959 --> 00:05:42,029\n',
#  '(Horses neighing)\n',
#  '\n',
#  '\n',
#  '\n',
#  '38\n',
#  '00:05:42,160 --> 00:05:43,798\n',
#  '(Galloping hooves)\n',
#  '\n',
#  '\n',
#  '\n',
#  '39\n',
#  '00:06:11,319 --> 00:06:12,354\n',
#  '(Snarling)\n',
#  '\n',
#  '\n',
#  '\n',
#  '40\n',
#  '00:06:14,159 --> 00:06:15,478\n',
#  '(Chittering)\n',
#  '\n',
#  '\n',
#  '\n',
#  '41\n',
#  '00:06:24,279 --> 00:06:26,156\n',
#  '(Coughing)\n',
#  '\n',
#  '\n',
#  '\n',
#  '42\n',
#  '00:06:27,960 --> 00:06:29,678\n',
#  '(Coughing)\n',
#  '\n',
#  '\n',
#  '\n',
#  '43\n',
#  '00:06:29,800 --> 00:06:31,711\n',
#  '(Panting)\n',
#  '\n',
#  '\n',
#  '\n',
#  '44\n',
#  '00:06:31,840 --> 00:06:33,512\n',
#  '(Laboured breathing)\n',
#  '\n',
#  '\n',
#  '\n',
#  '45\n',
#  '00:06:34,560 --> 00:06:36,312\n',
#  '(Snarling)\n',
#  '\n',
#  '\n',
#  '\n',
#  '46\n',
#  '00:06:38,680 --> 00:06:40,272\n',
#  '(GBSPS)\n',
#  '\n',
#  '\n',
#  '\n',
#  '47\n',
#  '00:06:44,960 --> 00:06:46,473\n',
#  '(Crackling)\n',
#  '\n',
#  '\n',
#  '\n',
#  '48\n',
#  '00:06:54,599 --> 00:06:56,157\n',
#  '(Chittering)\n',
#  '\n',
#  '\n',
#  '\n',
#  '49\n',
#  '00:08:39,319 --> 00:08:41,230\n',
#  '(Galloping hooves)\n',
#  '\n',
#  '\n',
#  '\n',
#  '50\n',
#  '00:09:20,000 --> 00:09:21,353\n',
#  '(Stamps)\n',
#  '\n',
#  '\n',
#  '\n',
#  '51\n',
#  '00:09:25,839 --> 00:09:28,228\n',
#  "Go on, Father's watching.\n",
#  '\n',
#  '\n',
#  '\n',
#  '52\n',
#  '00:09:30,359 --> 00:09:31,951\n',
#  'And your mother.\n',
#  '\n',
#  '\n',
#  '\n',
#  '53\n',
#  '00:09:37,920 --> 00:09:41,071\n',
#  'Fine work. as always.\n',
#  'Well done.\n',
#  '\n',
#  '\n',
#  '\n',
#  '54\n',
#  '00:09:41,200 --> 00:09:42,838\n',
#  'Thank you.\n',
#  '\n',
#  '\n',
#  '\n',
#  '55\n',
#  '00:09:42,920 --> 00:09:46,629\n',
#  "I love the detail that you've managed\n",
#  'to get in these comers.\n',
#  '\n',
#  '\n',
#  '\n',
#  '56\n',
#  '00:09:46,720 --> 00:09:48,472\n',
#  'Quite beautiful.\n',
#  '\n',
#  '\n',
#  '\n',
#  '57\n',
#  '00:09:48,600 --> 00:09:50,397\n',
#  'The stitching...\n',
#  '\n',
#  '\n',
#  '\n',
#  '58\n',
#  '00:09:50,520 --> 00:09:52,590\n',
#  'Oh, no, no, no. This stitch is very...\n',
#  '\n',
#  '\n',
#  '\n',
#  '59\n',
#  '00:09:52,720 --> 00:09:54,119\n',
#  '(Arrows impacting, men laughing)\n',
#  '\n',
#  '\n',
#  '\n',
#  '60\n',
#  '00:09:54,280 --> 00:09:56,157\n',
#  "- It's beautiful.\n",
#  '- Thank you.\n',
#  '\n',
#  '\n',
#  '\n',
#  '61\n',
#  '00:10:02,999 --> 00:10:04,990\n',
#  '(Arrow impacting)\n',
#  '\n',
#  '\n',
#  '\n',
#  '62\n',
#  '00:10:08,639 --> 00:10:10,595\n',
#  '- (Sighs)\n',
#  '- (Laughing)\n',
#  '\n',
#  '\n',
#  '\n',
#  '63\n',
#  '00:10:10,679 --> 00:10:13,318\n',
#  'And which one of you\n',
#  'was a marksman at ten?\n',
#  '\n',
#  '\n',
#  '\n',
#  '64\n',
#  '00:10:14,320 --> 00:10:15,753\n',
#  'Keep practicing, Bran.\n',
#  '\n',
#  '\n',
#  '\n',
#  '65\n',
#  '00:10:17,839 --> 00:10:19,716\n',
#  'Go on.\n',
#  '\n',
#  '\n',
#  '\n',
#  '66\n',
#  '00:10:19,840 --> 00:10:22,400\n',
#  "Don't think too much, Bran.\n",
#  '\n',
#  '\n',
#  '\n',
#  '67\n',
#  '00:10:24,720 --> 00:10:25,835\n',
#  'Relax your bow arm.\n',
#  '\n',
#  '\n',
#  '\n',
#  '68\n',
#  '00:10:35,559 --> 00:10:37,311\n',
#  '(Men laughing)\n',
#  '\n',
#  '\n',
#  '\n',
#  '69\n',
#  '00:10:38,480 --> 00:10:39,879\n',
#  '- Quick Branl\n',
#  '- Faster.\n',
#  '\n',
#  '\n',
#  '\n',
#  '70\n',
#  '00:10:41,400 --> 00:10:43,311\n',
#  'Lord Starkl\n',
#  '\n',
#  '\n',
#  '\n',
#  '71\n',
#  '00:10:45,280 --> 00:10:46,269\n',
#  'My lady.\n',
#  '\n',
#  '\n',
#  '\n',
#  '72\n',
#  '00:10:47,280 --> 00:10:49,396\n',
#  'A guardsman just rode in from the hills.\n',
#  '\n',
#  '\n',
#  '\n',
#  '73\n',
#  '00:10:49,520 --> 00:10:52,398\n',
#  "They've ptured a deserter\n",
#  "from the Night's Watch.\n",
#  '\n',
#  '\n',
#  '\n',
#  '74\n',
#  '00:10:55,559 --> 00:10:57,629\n',
#  'Get the lads to saddle their horses.\n',
#  '\n',
#  '\n',
#  '\n',
#  '75\n',
#  '00:10:57,720 --> 00:10:59,597\n',
#  'Do you have to?\n',
#  '\n',
#  '\n',
#  '\n',
#  '76\n',
#  '00:10:59,720 --> 00:11:01,711\n',
#  'He swore an oath, Cat.\n',
#  '\n',
#  '\n',
#  '\n',
#  '77\n',
#  '00:11:01,840 --> 00:11:03,751\n',
#  'Law is law, my lady.\n',
#  '\n',
#  '\n',
#  '\n',
#  '78\n',
#  '00:11:04,720 --> 00:11:06,711\n',
#  "Tell Bran he's coming too.\n",
#  '\n',
#  '\n',
#  '\n',
#  '79\n',
#  '00:11:08,559 --> 00:11:10,072\n',
#  'Ned.\n',
#  '\n',
#  '\n',
#  '\n',
#  '80\n',
#  '00:11:10,200 --> 00:11:12,395\n',
#  'Ten is too young\n',
#  'to see such things.\n',
#  '\n',
#  '\n',
#  '\n',
#  '81\n',
#  '00:11:12,520 --> 00:11:13,999\n',
#  "He won't be a boy forever.\n",
#  '\n',
#  '\n',
#  '\n',
#  '82\n',
#  '00:11:15,920 --> 00:11:17,512\n',
#  'And winter is coming.\n',
#  '\n',
#  '\n',
#  '\n',
#  '83\n',
#  '00:11:35,879 --> 00:11:37,995\n',
#  'Good lad, go run back and get the rest.\n',
#  '\n',
#  '\n',
#  '\n',
#  '84\n',
#  '00:11:43,879 --> 00:11:45,392\n',
#  'White walkers.\n',
#  '\n',
#  '\n',
#  '\n',
#  '85\n',
#  '00:11:45,519 --> 00:11:48,113\n',
#  'I saw the white walkers.\n',
#  '\n',
#  '\n',
#  '\n',
#  '86\n',
#  '00:11:48,239 --> 00:11:50,036\n',
#  'White walkers.\n',
#  '\n',
#  '\n',
#  '\n',
#  '87\n',
#  '00:11:50,159 --> 00:11:53,071\n',
#  'The white walkers, I saw them.\n',
#  '\n',
#  '\n',
#  '\n',
#  '88\n',
#  '00:11:53,199 --> 00:11:54,757\n',
#  '(Exhales)\n',
#  '\n',
#  '\n',
#  '\n',
#  '89\n',
#  '00:12:01,519 --> 00:12:03,077\n',
#  'I know I broke my oath.\n',
#  '\n',
#  '\n',
#  '\n',
#  '90\n',
#  '00:12:04,239 --> 00:12:05,672\n',
#  "And I know I'm a deserter.\n",
#  '\n',
#  '\n',
#  '\n',
#  '91\n',
#  '00:12:06,519 --> 00:12:09,079\n',
#  'I should have gone back to the Wall\n',
#  'and warned them, but...\n',
#  '\n',
#  '\n',
#  '\n',
#  '92\n',
#  '00:12:10,200 --> 00:12:12,111\n',
#  'lsawwhatlsaw.\n',
#  '\n',
#  '\n',
#  '\n',
#  '93\n',
#  '00:12:12,239 --> 00:12:13,718\n',
#  'I saw the white walkers.\n',
#  '\n',
#  '\n',
#  '\n',
#  '94\n',
#  '00:12:15,600 --> 00:12:17,318\n',
#  'People need to know.\n',
#  '\n',
#  '\n',
#  '\n',
#  '95\n',
#  '00:12:19,439 --> 00:12:21,157\n',
#  'If you n get word to my family...\n',
#  '\n',
#  '\n',
#  '\n',
#  '96\n',
#  '00:12:21,320 --> 00:12:23,515\n',
#  "tell them I'm no coward.\n",
#  '\n',
#  '\n',
#  '\n',
#  '97\n',
#  '00:12:23,640 --> 00:12:25,517\n',
#  "Tell them I'm sorry.\n",
#  '\n',
#  '\n',
#  '\n',
#  '98\n',
#  '00:12:41,840 --> 00:12:43,432\n',
#  '(Whispers) Forgive me, Lord.\n',
#  '\n',
#  '\n',
#  '\n',
#  '99\n',
#  '00:12:47,640 --> 00:12:49,710\n',
#  'In the name of Robert\n',
#  'of the House Baratheon,\n',
#  '\n',
#  '\n',
#  '\n',
#  '100\n',
#  '00:12:49,799 --> 00:12:51,710\n',
#  '- the ﬁrst of his name...\n',
#  "- Don't look away.\n",
#  '\n',
#  '\n',
#  '\n',
#  '101\n',
#  '00:12:51,799 --> 00:12:54,552\n',
#  '- ..King of the Andals and the First Men...\n',
#  '- Father will know if you do.\n',
#  '\n',
#  '\n',
#  '\n',
#  '102\n',
#  '00:12:54,639 --> 00:12:57,870\n',
#  '..Lord of the Seven Kingdoms\n',
#  'and protector of the realm,\n',
#  '\n',
#  '\n',
#  '\n',
#  '103\n',
#  '00:12:58,000 --> 00:13:00,753\n',
#  'l, Eddard of the House Stark.\n',
#  '\n',
#  '\n',
#  '\n',
#  '104\n',
#  '00:13:00,879 --> 00:13:03,268\n',
#  'Lord of Winterfell\n',
#  'and Warden of the North,\n',
#  '\n',
#  '\n',
#  '\n',
#  '105\n',
#  '00:13:03,399 --> 00:13:05,788\n',
#  'sentence you to die.\n',
#  '\n',
#  '\n',
#  '\n',
#  '106\n',
#  '00:13:20,000 --> 00:13:21,558\n',
#  'You did well.\n',
#  '\n',
#  '\n',
#  '\n',
#  '107\n',
#  '00:13:48,600 --> 00:13:50,033\n',
#  'You understand why I did it?\n',
#  '\n',
#  '\n',
#  '\n',
#  '108\n',
#  '00:13:50,160 --> 00:13:51,957\n',
#  'Jon said he was a deserter.\n',
#  '\n',
#  '\n',
#  '\n',
#  '109\n',
#  '00:13:52,080 --> 00:13:54,514\n',
#  'But do you understand\n',
#  'why I had to kill him?\n',
#  '\n',
#  '\n',
#  '\n',
#  '110\n',
#  '00:13:54,639 --> 00:13:56,152\n',
#  '"Our way is the old way"?\n',
#  '\n',
#  '\n',
#  '\n',
#  '111\n',
#  '00:13:57,759 --> 00:14:01,274\n',
#  'The man who passes the sentence\n',
#  'should swing the sword.\n',
#  '\n',
#  '\n',
#  '\n',
#  '112\n',
#  '00:14:02,279 --> 00:14:04,554\n',
#  'Is it true he saw the white walkers?\n',
#  '\n',
#  '\n',
#  '\n',
#  '113\n',
#  '00:14:06,480 --> 00:14:09,358\n',
#  'The white walkers have been gone\n',
#  'for thousands of years.\n',
#  '\n',
#  '\n',
#  '\n',
#  '114\n',
#  '00:14:10,440 --> 00:14:11,919\n',
#  'So he was lying?\n',
#  '\n',
#  '\n',
#  '\n',
#  '115\n',
#  '00:14:16,199 --> 00:14:18,429\n',
#  'A madman sees what he sees.\n',
#  '\n',
#  '\n',
#  '\n',
#  '116\n',
#  '00:14:43,320 --> 00:14:45,151\n',
#  'What is it?\n',
#  '\n',
#  '\n',
#  '\n',
#  '117\n',
#  '00:14:47,480 --> 00:14:49,038\n',
#  'Mountain lion?\n',
#  '\n',
#  '\n',
#  '\n',
#  '118\n',
#  '00:14:50,400 --> 00:14:52,595\n',
#  'There are no mountain lions\n',
#  'in these woods.\n',
#  '\n',
#  '\n',
#  '\n',
#  '119\n',
#  '00:15:18,759 --> 00:15:20,351\n',
#  '(Pup whines)\n',
#  '\n',
#  '\n',
#  '\n',
#  '120\n',
#  '00:15:36,880 --> 00:15:38,598\n',
#  "It's a freak\n",
#  '\n',
#  '\n',
#  '\n',
#  '121\n',
#  '00:15:39,920 --> 00:15:41,148\n',
#  "It's a direwolf.\n",
#  '\n',
#  '\n',
#  '\n',
#  '122\n',
#  '00:15:50,039 --> 00:15:52,189\n',
#  'Tough old beast.\n',
#  '\n',
#  '\n',
#  '\n',
#  '123\n',
#  '00:15:54,399 --> 00:15:56,390\n',
#  'There are no direwolves\n',
#  'south of the Wall.\n',
#  '\n',
#  '\n',
#  '\n',
#  '124\n',
#  '00:15:57,239 --> 00:15:58,467\n',
#  'Now there are ﬁve.\n',
#  '\n',
#  '\n',
#  '\n',
#  '125\n',
#  '00:16:00,040 --> 00:16:01,632\n',
#  'You want to hold it?\n',
#  '\n',
#  '\n',
#  '\n',
#  '126\n',
#  '00:16:03,079 --> 00:16:05,115\n',
#  '(Pup whimpers)\n',
#  '\n',
#  '\n',
#  '\n',
#  '127\n',
#  '00:16:05,999 --> 00:16:07,432\n',
#  '(Bran) Where will they go?\n',
#  '\n',
#  '\n',
#  '\n',
#  '128\n',
#  '00:16:07,560 --> 00:16:09,198\n',
#  "Their mother's dead.\n",
#  '\n',
#  '\n',
#  '\n',
#  '129\n',
#  '00:16:09,319 --> 00:16:10,798\n',
#  "They don't belong down here.\n",
#  '\n',
#  '\n',
#  '\n',
#  '130\n',
#  '00:16:10,920 --> 00:16:14,549\n',
#  'Better a quick death.\n',
#  "They won't last without their mother.\n",
#  '\n',
#  '\n',
#  '\n',
#  '131\n',
#  '00:16:14,679 --> 00:16:16,590\n',
#  '- Right. Give it here.\n',
#  '- Nol\n',
#  '\n',
#  '\n',
#  '\n',
#  '132\n',
#  '00:16:16,719 --> 00:16:18,311\n',
#  '- (Whimpers)\n',
#  '- Put away your blade.\n',
#  '\n',
#  '\n',
#  '\n',
#  '133\n',
#  '00:16:18,439 --> 00:16:21,237\n',
#  '- I take orders from your father, not you.\n',
#  '- Please, Fatherl\n',
#  '\n',
#  '\n',
#  '\n',
#  '134\n',
#  '00:16:21,359 --> 00:16:23,077\n',
#  "I'm sorry, Bran.\n",
#  '\n',
#  '\n',
#  '\n',
#  '135\n',
#  '00:16:23,199 --> 00:16:24,188\n',
#  'Lord Stark?\n',
#  '\n',
#  '\n',
#  '\n',
#  '136\n',
#  '00:16:28,680 --> 00:16:30,671\n',
#  'One for each of the Stark children.\n',
#  '\n',
#  '\n',
#  '\n',
#  '137\n',
#  '00:16:30,799 --> 00:16:33,188\n',
#  '- (Pup cries)\n',
#  '- The direwolf is the sigil of your house.\n',
#  '\n',
#  '\n',
#  '\n',
#  '138\n',
#  '00:16:34,519 --> 00:16:36,635\n',
#  'They were meant to have them.\n',
#  '\n',
#  '\n',
#  '\n',
#  '139\n',
#  '00:16:41,680 --> 00:16:43,750\n',
#  'You will train them yourselves.\n',
#  '\n',
#  '\n',
#  '\n',
#  '140\n',
#  '00:16:43,880 --> 00:16:45,677\n',
#  'You will feed them yourselves.\n',
#  '\n',
#  '\n',
#  '\n',
#  '141\n',
#  '00:16:45,799 --> 00:16:48,552\n',
#  'And ifthey die, you will bury them yourselves.\n',
#  '\n',
#  '\n',
#  '\n',
#  '142\n',
#  '00:16:56,839 --> 00:16:58,477\n',
#  'What about you?\n',
#  '\n',
#  '\n',
#  '\n',
#  '143\n',
#  '00:16:59,319 --> 00:17:00,911\n',
#  "I'm not a Stark.\n",
#  '\n',
#  '\n',
#  '\n',
#  '144\n',
#  '00:17:01,040 --> 00:17:03,031\n',
#  'Get on.\n',
#  '\n',
#  '\n',
#  '\n',
#  '145\n',
#  '00:17:09,759 --> 00:17:11,750\n',
#  '(Whimpering)\n',
#  '\n',
#  '\n',
#  '\n',
#  '146\n',
#  '00:17:12,680 --> 00:17:14,079\n',
#  'What is it?\n',
#  '\n',
#  '\n',
#  '\n',
#  '147\n',
#  '00:17:18,119 --> 00:17:21,475\n',
#  'The runt of the litter.\n',
#  "That one's yours, Snow.\n",
#  '\n',
#  '\n',
#  '\n',
#  '148\n',
#  '00:17:30,239 --> 00:17:31,672\n',
#  '(Bells tolling)\n',
#  '\n',
#  '\n',
#  '\n',
#  '149\n',
#  '00:18:19,200 --> 00:18:22,237\n',
#  'As your brother,\n',
#  "I feel it's my duty to warn you...\n",
#  '\n',
#  '\n',
#  '\n',
#  '150\n',
#  '00:18:23,400 --> 00:18:25,311\n',
#  'you worry too much.\n',
#  '\n',
#  '\n',
#  '\n',
#  '151\n',
#  '00:18:25,440 --> 00:18:28,671\n',
#  "- It's starting to show.\n",
#  '- And you never worry about anything.\n',
#  '\n',
#  '\n',
#  '\n',
#  '152\n',
#  '00:18:29,920 --> 00:18:33,674\n',
#  'When we were seven and you jumped off\n',
#  'the cliffs at Casterly Rock.\n',
#  '\n',
#  '\n',
#  '\n',
#  '153\n',
#  '00:18:33,800 --> 00:18:37,952\n',
#  '100-foot drop into the water...\n',
#  'you were never afraid.\n',
#  '\n',
#  '\n',
#  '\n',
#  '154\n',
#  '00:18:38,079 --> 00:18:40,639\n',
#  'There was nothing to be afraid of\n',
#  'until you told Father.\n',
#  '\n',
#  '\n',
#  '\n',
#  '155\n',
#  '00:18:40,719 --> 00:18:44,189\n',
#  "(Mimim) 'We're Lannisters.\n",
#  'Lannisters don\'t act like fools."\n',
#  '\n',
#  '\n',
#  '\n',
#  '156\n',
#  '00:18:46,479 --> 00:18:49,915\n',
#  '- What if Jon Arryn told someone?\n',
#  '- But who would he tell?\n',
#  '\n',
#  '\n',
#  '\n',
#  '157\n',
#  '00:18:51,200 --> 00:18:52,269\n',
#  'My husband.\n',
#  '\n',
#  '\n',
#  '\n',
#  '158\n',
#  '00:18:52,400 --> 00:18:55,995\n',
#  'If he told the king, both our heads would be\n',
#  'skewered on the city gates by now.\n',
#  '\n',
#  '\n',
#  '\n',
#  '159\n',
#  '00:18:57,519 --> 00:19:00,511\n',
#  "Whatever Jon Arryn knew or didn't know,\n",
#  'it died with him.\n',
#  '\n',
#  '\n',
#  '\n',
#  '160\n',
#  ...]

# %%
print(new_lines)
# Out:
# ['00:00:10,599 --> 00:00:13,113 (Gate rumbling, chains rattling) 00:00:41,120 --> 00:00:43,156 (Horse snorts) 00:00:55,520 --> 00:00:57,397 (Rumbling, chain rattling) 00:01:40,159 --> 00:01:41,717 (Wind whistling) 00:01:52,639 --> 00:01:54,789 - Easy, boy. - (Grunts) 00:02:53,760 --> 00:02:55,796 (Horse whinnies) 00:03:04,799 --> 00:03:06,755 (Man) What do you expect? They\'re savages. 00:03:06,880 --> 00:03:09,110 One lot steals a goat from another lot, 00:03:09,240 --> 00:03:11,515 before you know it they\'re ripping each other to pieces. 00:03:11,639 --> 00:03:13,948 I\'ve never seen wildlings do a thing like this. 00:03:14,080 --> 00:03:16,196 I never seen a thing like this, not ever in my life. 00:03:16,319 --> 00:03:18,389 - (Horse snorts) - How close did you get? 00:03:18,480 --> 00:03:21,756 - Close as any man would. - We should head back to the Wall. 00:03:24,280 --> 00:03:25,679 Do the dead frighten you? 00:03:25,840 --> 00:03:27,876 Our orders were to track the wildlings. 00:03:27,999 --> 00:03:31,036 We tracked them. They won‘t trouble us no more. 00:03:31,159 --> 00:03:33,514 You don‘t think he\'ll ask us how they died? 00:03:35,679 --> 00:03:37,397 Get back on your horse. 00:03:38,879 --> 00:03:40,676 (Sighs, mutters) 00:03:41,879 --> 00:03:44,313 Whatever did it to them could do it to us. 00:03:44,400 --> 00:03:45,958 They even killed the children. 00:03:46,840 --> 00:03:48,751 It\'s a good thing we\'re not children. 00:03:50,079 --> 00:03:52,798 You want to run away south, run away. 00:03:52,920 --> 00:03:55,718 Of course, they will behead you as a deserter. 00:03:55,840 --> 00:03:57,831 If I don\'t catch you ﬁrst. 00:04:00,120 --> 00:04:02,350 Get back on your horse. 00:04:02,480 --> 00:04:04,675 I won\'t say it again. 00:04:21,639 --> 00:04:23,675 (Shrill animal ll) 00:04:34,519 --> 00:04:36,953 Your dead men seem to have moved mp. 00:04:37,600 --> 00:04:39,192 They were here. 00:04:42,440 --> 00:04:44,032 See where they went. 00:04:58,840 --> 00:05:01,400 (Echoing creature cries) 00:05:28,639 --> 00:05:30,436 What is it? 00:05:31,720 --> 00:05:32,755 It\'s... 00:05:33,800 --> 00:05:35,597 (Cracking, creaking) 00:05:37,840 --> 00:05:39,831 (Distant scream) 00:05:39,959 --> 00:05:42,029 (Horses neighing) 00:05:42,160 --> 00:05:43,798 (Galloping hooves) 00:06:11,319 --> 00:06:12,354 (Snarling) 00:06:14,159 --> 00:06:15,478 (Chittering) 00:06:24,279 --> 00:06:26,156 (Coughing) 00:06:27,960 --> 00:06:29,678 (Coughing) 00:06:29,800 --> 00:06:31,711 (Panting) 00:06:31,840 --> 00:06:33,512 (Laboured breathing) 00:06:34,560 --> 00:06:36,312 (Snarling) 00:06:38,680 --> 00:06:40,272 (GBSPS) 00:06:44,960 --> 00:06:46,473 (Crackling) 00:06:54,599 --> 00:06:56,157 (Chittering) 00:08:39,319 --> 00:08:41,230 (Galloping hooves) 00:09:20,000 --> 00:09:21,353 (Stamps) 00:09:25,839 --> 00:09:28,228 Go on, Father\'s watching. 00:09:30,359 --> 00:09:31,951 And your mother. 00:09:37,920 --> 00:09:41,071 Fine work. as always. Well done. 00:09:41,200 --> 00:09:42,838 Thank you. 00:09:42,920 --> 00:09:46,629 I love the detail that you\'ve managed to get in these comers. 00:09:46,720 --> 00:09:48,472 Quite beautiful. 00:09:48,600 --> 00:09:50,397 The stitching... 00:09:50,520 --> 00:09:52,590 Oh, no, no, no. This stitch is very... 00:09:52,720 --> 00:09:54,119 (Arrows impacting, men laughing) 00:09:54,280 --> 00:09:56,157 - It\'s beautiful. - Thank you. 00:10:02,999 --> 00:10:04,990 (Arrow impacting) 00:10:08,639 --> 00:10:10,595 - (Sighs) - (Laughing) 00:10:10,679 --> 00:10:13,318 And which one of you was a marksman at ten? 00:10:14,320 --> 00:10:15,753 Keep practicing, Bran. 00:10:17,839 --> 00:10:19,716 Go on. 00:10:19,840 --> 00:10:22,400 Don\'t think too much, Bran. 00:10:24,720 --> 00:10:25,835 Relax your bow arm. 00:10:35,559 --> 00:10:37,311 (Men laughing) 00:10:38,480 --> 00:10:39,879 - Quick Branl - Faster. 00:10:41,400 --> 00:10:43,311 Lord Starkl 00:10:45,280 --> 00:10:46,269 My lady. 00:10:47,280 --> 00:10:49,396 A guards ...

# %%
from textblob import TextBlob

# %%
blob=TextBlob(new_lines)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-4482575ea70e> in <module>()
# ----> 1 blob=TextBlob(new_lines)
#
# ~/anaconda3/envs/Lxml/lib/python3.5/site-packages/textblob/blob.py in __init__(self, text, tokenizer, pos_tagger, np_extractor, analyzer, parser, classifier, clean_html)
#     362         if not isinstance(text, basestring):
#     363             raise TypeError('The `text` argument passed to `__init__(text)` '
# --> 364                             'must be a string, not {0}'.format(type(text)))
#     365         if clean_html:
#     366             raise NotImplementedError("clean_html has been deprecated. "
#
# TypeError: The `text` argument passed to `__init__(text)` must be a string, not <class 'list'>

# %%
blob.tags
# Out:
# [('At', 'IN'),
#  ('eight', 'CD'),
#  ("o'clock", 'NN'),
#  ('on', 'IN'),
#  ('Thursday', 'NNP'),
#  ('morning', 'NN'),
#  ('Arthur', 'NNP'),
#  ('did', 'VBD'),
#  ("n't", 'RB'),
#  ('feel', 'VB'),
#  ('very', 'RB'),
#  ('good', 'JJ'),
#  ('new', 'JJ'),
#  ('line', 'NN'),
#  ('Aman', 'NNP'),
#  ('is', 'VBZ'),
#  ('coming', 'VBG')]

# %%
for sen in blob.sentences:
    print(round(sen.sentiment.polarity,2))
# Out:
# 0.91
# 0.14

# %%
sent=blob.sentences

# %%
for i in sent:
    print(i)
# Out:
# At eight o'clock on Thursday morning Arthur didn't feel very good.
# new line Aman is coming

# %%
blob.translate(to="fr")
# Out:
# TextBlob("Jeudi matin, à huit heures, Arthur ne se sentait pas très bien. nouvelle ligne Aman arrive")

# %%
for i in blob.sentences:
    print(i)
# Out:
# At eight o'clock on Thursday morning Arthur didn't feel very good.
# new line Aman is coming

# %%
import pysrt

# %%
subs=pysrt.open('/home/berhe/Desktop/LIMSI/TLP_thesis/subtitles/GameOfThrones.Season01.Episode01.en.srt')

# %%
sub=subs[0]

# %%
sub

# %%
text=sub.text

# %%
text
# Out:
# u'(Gate rumbling, chains rattling)'

# %%
text_tag=sub.text_without_tags

# %%
text_tag
# Out:
# u'(Gate rumbling, chains rattling)'

# %%
start=sub.start.to_time()

# %%
start
# Out:
# datetime.time(0, 0, 10, 599000)

# %%
end =sub.end.to_time()

# %%
end
# Out:
# datetime.time(0, 0, 13, 113000)
